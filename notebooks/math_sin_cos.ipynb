# %%
import numpy as np 
import matplotlib.pyplot as plt  
   
x = np.arange(0, 7 * np.pi, 0.01) 

# Синус
plt.subplot(3, 1, 1)
plt.plot(x, np.sin(x))
plt.title('Синус')

# Косинус
plt.subplot(3, 1, 3)
plt.plot(x, np.cos(x))
plt.title('Косинус')

plt.show()
